# %% [markdown]
# Pre Preprocessing

# %%
import mne

raw = mne.io.read_raw_brainvision("I:/adhd/adhd-patients/sub-88015117/ses-1/eeg/sub-88015117_ses-1_task-restEC_eeg.vhdr", preload=True)

raw.plot()

raw.plot_psd(fmax=100, average=True, spatial_colors=False)
# Out:
# Extracting parameters from I:/adhd/adhd-patients/sub-88015117/ses-1/eeg/sub-88015117_ses-1_task-restEC_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 60023  =      0.000 ...   120.046 secs...
# <MNEBrowseFigure size 800x800 with 4 Axes>
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.096 (s)
# Plotting power spectral density (dB=True).
# i:\Python313\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
import os
import mne

# Load the EEG data
raw = mne.io.read_raw_brainvision("I:/adhd/adhd-patients/sub-88015117/ses-1/eeg/sub-88015117_ses-1_task-restEC_eeg.vhdr", preload=True)

# Select the last 50 seconds of the recording
raw.crop(tmax=raw.times[-1] - 50)

# Apply band-pass filtering (0.5 to 100 Hz)
raw.filter(0.5, 100, fir_design='firwin')

# Apply notch filter at 50 Hz
raw.notch_filter(50, fir_design='firwin')

raw.set_eeg_reference('average')

channel_types = {
"VPVA": "eog",
"VNVB": "eog",
"HPHL": "eog",
"HNHR": "eog",
"Erbs": "ecg",
"OrbOcc": "eog",
"Mass": "emg",  
}

raw.set_channel_types(channel_types)
print(raw.get_channel_types())

# Set the montage (10-10 system)
montage = mne.channels.make_standard_montage("standard_1020")
raw.set_montage(montage)

# Apply ICA for artifact removal 
ica = mne.preprocessing.ICA(n_components=25, method='fastica', max_iter=500, random_state=42)

# Fit ICA
ica.fit(raw)

# Automatically detect artifacts
ecg_indices, _ = ica.find_bads_ecg(raw)
eog_indices, _ = ica.find_bads_eog(raw)
emg_indices, _ = ica.find_bads_muscle(raw)  # Detect EMG artifacts

# Exclude artifacts and apply ICA
ica.exclude = ecg_indices + eog_indices + emg_indices
raw = ica.apply(raw)

raw.plot()
raw.plot_psd(fmax=100, average=True, spatial_colors=False)
# Out:
# Extracting parameters from I:/adhd/adhd-patients/sub-88015117/ses-1/eeg/sub-88015117_ses-1_task-restEC_eeg.vhdr...
# Setting channel info structure...
# Reading 0 ... 60023  =      0.000 ...   120.046 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eog', 'eog', 'eog', 'eog', 'ecg', 'eog', 'emg']
# Fitting ICA to data using 26 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Selecting by number: 25 components
# Fitting ICA took 2.2s.
# Using threshold: 0.23 for CTPS ECG detection
# Using channel Erbs to identify heart beats.
# Setting up band-pass filter from 8 - 16 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 7.75 Hz)
# - Upper passband edge: 16.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 16.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# Number of ECG events detected : 76 (average pulse 65.09821836455002 / min.)
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 76 events and 501 original time points ...
# 1 bad epochs dropped
# Using EOG channels: VPVA, VNVB, HPHL, HNHR, OrbOcc
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# Effective window size : 4.096 (s)
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 10 ICA components
#     Projecting back using 26 PCA components
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.096 (s)
# Plotting power spectral density (dB=True).
# i:\Python313\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
